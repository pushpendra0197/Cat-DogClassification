# %%
import numpy as np
import pandas as pd
import tensorflow
import seaborn as sns
import matplotlib.pyplot as plt
import cv2
import joblib
from tensorflow import keras
import joblib

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
data=(r"C:\Users\KINGNICKS-DELL\Downloads\da\Data")

# %%
Train_ds=tensorflow.keras.utils.image_dataset_from_directory(data,image_size=(150,150), validation_split=0.2,seed=123,subset="training")
# Out:
# Found 8000 files belonging to 2 classes.
# Using 6400 files for training.

# %%
validation_ds=tensorflow.keras.utils.image_dataset_from_directory(data,image_size=(150,150), validation_split=0.2,seed=123,subset="validation",label_mode="int")
# Out:
# Found 8000 files belonging to 2 classes.
# Using 1600 files for validation.

# %%
for images,labels in Train_ds.take(5):
    for i in range(2):
       plt.subplot(1,2,i+1)
       img=images[i].numpy().astype("uint8")
       plt.imshow(img)
       plt.title(Train_ds.class_names[labels[i]])

# %%
autotune=tensorflow.data.AUTOTUNE

# %%
Train_ds=Train_ds.cache().shuffle(1000).prefetch(buffer_size=autotune)
validation_ds=validation_ds.cache().shuffle(1000).prefetch(buffer_size=autotune)

# %%
Train_ds
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 150, 150, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Conv2D,Flatten,MaxPool2D
from  tensorflow.keras import layers

# %%
normalization_layer=tensorflow.keras.layers.Rescaling(1./255)

# %%
data_augmentation=tensorflow.keras.Sequential([
                    layers.RandomFlip("horizontal",input_shape=(150,150,3)),
                    layers.RandomZoom(height_factor=0.1, width_factor=0.1)])

# %%
model=Sequential([
                  data_augmentation,
                  normalization_layer,
                  #conv 1 layer 
                  layers.Conv2D(64,(3,3),activation='relu'),
                  layers.MaxPool2D(),
    
                 
                  layers.Conv2D(32,3, padding="same",activation='relu'),
                  layers.MaxPool2D(),
            

                  layers.Flatten(),
                  layers.Dense(64,activation='relu'),
                  layers.Dense(32,activation='relu'),
                  layers.Dense(1,activation="sigmoid")])

# %%
model.summary()
# Out:
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ sequential_7 (Sequential)            │ (None, 150, 150, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ rescaling_1 (Rescaling)              │ (None, 150, 150, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_10 (Conv2D)                   │ (None, 148, 148, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_10 (MaxPooling2D)      │ (None, 74, 74, 64)          │               0 │
# ...

# %%
from tensorflow.keras.callbacks import  EarlyStopping

# %%
es=EarlyStopping(monitor='val_accuracy',patience=3,restore_best_weights=True)

# %%
model.compile(optimizer='adam',loss=tensorflow.keras.losses.binary_crossentropy,metrics=['accuracy'])

# %%
history=model.fit(Train_ds,validation_data=validation_ds,epochs=10,callbacks=[es])
# Out:
# Epoch 1/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 120s 579ms/step - accuracy: 0.5236 - loss: 0.7459 - val_accuracy: 0.5731 - val_loss: 0.6702
# Epoch 2/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 116s 580ms/step - accuracy: 0.6170 - loss: 0.6529 - val_accuracy: 0.6394 - val_loss: 0.6298
# Epoch 3/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 116s 582ms/step - accuracy: 0.6698 - loss: 0.6069 - val_accuracy: 0.6806 - val_loss: 0.5957
# Epoch 4/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 116s 581ms/step - accuracy: 0.6920 - loss: 0.5753 - val_accuracy: 0.6963 - val_loss: 0.5793
# Epoch 5/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 117s 586ms/step - accuracy: 0.7236 - loss: 0.5469 - val_accuracy: 0.6931 - val_loss: 0.5681
# Epoch 6/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 116s 578ms/step - accuracy: 0.7139 - loss: 0.5470 - val_accuracy: 0.7281 - val_loss: 0.5341
# Epoch 7/10
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 117s 586ms/step - accuracy: 0.7421 - loss: 0.5186 - val_accuracy: 0.7119 - val_loss: 0.6193
# Epoch 8/10
# ...

# %%
from tensorflow.keras.utils import load_img

# %%
path=(r"F:\download\pexels-photo-1170986.webp")

# %%
im=load_img(path,target_size=(150,150,3))
im
# Out:
# <PIL.Image.Image image mode=RGB size=150x150>

# %%
Image=np.expand_dims(im,axis=0)

# %%
pred=model.predict(Image)[0][0]
pred
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 0.5603812

# %%
pred=model.predict(Image)[0][0]
pred
if pred<=0.5:
    print("cat")
else:
    print("dog")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# dog

# %%
model.save("CNN.keras")

# %%
Model=joblib.load(r"C:\Users\KINGNICKS-DELL\Downloads\da\model.pkl")
Model
# Out:
# <Sequential name=sequential_1, built=True>

# %%
from tensorflow.keras.models import load_model

# %%
Model=load_model(r"C:\Users\KINGNICKS-DELL\Downloads\da\my_cnn_model.keras")

# %%
Model
# Out:
# <Sequential name=sequential_6, built=True>

# %%
Model.predict(Image)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step
# array([[0.29229712]], dtype=float32)

# %%
import modelbit

# %%
model=modelbit.login()

# %%
def Classification(Image):
    Image=cv2.resize(Image,dsize=(150,150),interpolation=cv2.INTER_AREA)
    final_image=np.expand_dims(Image,axis=0)
    pred=model.predict(Image)[0][0]
    if pred<0.5:
      return("Cat")
    else:
        return ("Dog")

# %%
Classification(Image)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 Classification(Image)
#
# Cell In[45], line 2, in Classification(Image)
#       1 def Classification(Image):
# ----> 2     Image=cv2.resize(Image,dsize=(150,150),interpolation=cv2.INTER_AREA)
#       3     final_image=np.expand_dims(Image,axis=0)
#       4     pred=model.predict(Image)[0][0]
#
# error: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\resize.cpp:3789: error: (-215:Assertion failed) !dsize.empty() in function 'cv::hal::resize'

# %%
img.resize(
